# %% [markdown]
# # 1. Introduction & Problem Statement

# %% [markdown]
# **COMP9444: Neural Networks and Deep Learning**
# **Project 077: SQL Prompt Generation from Natural Language Queries**
# **Group Members:**
# - Yuki Chiu (z5711251)
# - Sharon Hu (z5423174)
# - Tony Hsieh (z5710871)
# - Sean Leong (z5421567)

# %% [markdown]
# ## 1.1 Introduction

# %% [markdown]
# ## 1.2 Problem Statement

# %% [markdown]
# ## 1.3 Project Objectives

# %% [markdown]
# ## 1.4 Related Work

# %% [markdown]
# ## 1.5 Report Structure
